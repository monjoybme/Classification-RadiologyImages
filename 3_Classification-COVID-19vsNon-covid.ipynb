# %% [markdown]
# **Google Drive Mount**

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Load packages**

# %%
import tensorflow.keras.activations as Act

# %%
import tensorflow
import tensorflow.keras.layers as Layers
import tensorflow.keras.activations as Activations

# %%
import tensorflow.keras.layers as Layers
import tensorflow.keras.activations as Activations
import tensorflow.keras.models as Models
import tensorflow.keras.optimizers as Optimizer
import tensorflow.keras.metrics as Metrics
import tensorflow.keras.utils as Utils
#from keras.utils.vis_utils import model_to_dot
import os
import matplotlib.pyplot as plot
import cv2
import numpy as np
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix as CM
from random import randint
#from IPython.display import SVG
import matplotlib.gridspec as gridspec

# %% [markdown]
# Now, We need to prepare our data to feed into the model. There is a builtin method in [Keras](https://keras.io/preprocessing/image/) that can extract your images from folders.
#
# Following is the gernalized function used to extract data from the directory.

# %%
def get_images(directory):
    Images = []
    Labels = []
    label = 0

    for labels in os.listdir(directory): #Main Directory where each class label is present as folder name.
        if labels == 'Normal':
            label = 0
        elif labels == 'COVID-19':
            label = 1
        for image_file in os.listdir(directory+labels): #Extracting the file name of the image from Class Label folder
            image = cv2.imread(directory+labels+r'/'+image_file) #Reading the image (OpenCV)
            image = cv2.resize(image,(150,150)) #Resize the image, Some images are different sizes. (Resizing is very Important)
            Images.append(image)
            Labels.append(label)

    return shuffle(Images,Labels,random_state=12345) #Shuffle the dataset you just prepared.

def get_classlabel(class_code):
    labels = {0:'Normal', 1:'COVID-19'}
    return labels[class_code]

# %%
Images, Labels = get_images('/Users/saham2/Downloads/Radiology_workshop_monjoy/classification_raw_data/train_data') #Extract the training images from the folders.

Images = np.array(Images) #converting the list of images to numpy array.
Labels = np.array(Labels)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 Images, Labels = get_images('/Users/saham2/Downloads/Radiology_workshop_monjoy/classification_raw_data/train_data') #Extract the training images from the folders.
#       3 Images = np.array(Images) #converting the list of images to numpy array.
#       4 Labels = np.array(Labels)
#
# Cell In[10], line 11, in get_images(directory)
#       9 elif labels == 'COVID-19':
#      10     label = 1
# ---> 11 for image_file in os.listdir(directory+labels): #Extracting the file name of the image from Class Label folder
#      12     image = cv2.imread(directory+labels+r'/'+image_file) #Reading the image (OpenCV)
#      13     image = cv2.resize(image,(150,150)) #Resize the image, Some images are different sizes. (Resizing is very Important)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/saham2/Downloads/Radiology_workshop_monjoy/classification_raw_data/train_dataCOVID-19'

# %%
Labels
# Out:
# array([1, 0, 0, ..., 1, 1, 0])

# %%
Images.shape
# Out:
# (1684, 150, 150, 3)

# %% [markdown]
# Lets find shape of our traing data.
#
# As you see, The Training data is in shape of (Number of Training Images, Width of image, Height of image, Channel of image). This shape is very important. If you didnot resize the images to same size. It should be (No. of images,) shape. So, using this shape you cant feed the images to the model.

# %%
print("Shape of Images:",Images.shape)
print("Shape of Labels:",Labels.shape)
# Out:
# Shape of Images: (1684, 150, 150, 3)
# Shape of Labels: (1684,)

# %% [markdown]
# Let us look some random images of our dataset.

# %%
f,ax = plot.subplots(5,5)
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
    for j in range(0,5,1):
        rnd_number = randint(0,len(Images))
        ax[i,j].imshow(Images[rnd_number])
        ax[i,j].set_title(get_classlabel(Labels[rnd_number]))
        ax[i,j].axis('off')

# %% [markdown]
# Now, Create the CNN model to predict the class labels.This is the basic CNN model.

# %%
model = Models.Sequential()
model.add(Layers.Conv2D(200,kernel_size=(3,3),activation='relu',input_shape=(150,150,3)))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(140,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(100,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(50,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(50,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Flatten())
model.add(Layers.Dense(180,activation='relu'))
#model.add(Layers.Dense(100,activation='relu'))
model.add(Layers.Dense(50,activation='relu'))
model.add(Layers.Dropout(rate=0.5))
model.add(Layers.Dense(1,activation='sigmoid'))

model.compile(optimizer=Optimizer.Adam(lr=0.0001),loss='binary_crossentropy',metrics=['accuracy'])

model.summary()
#SVG(model_to_dot(model).create(prog='dot', format='svg'))
Utils.plot_model(model,to_file='model.png',show_shapes=True)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_77 (Conv2D)          (None, 148, 148, 200)     5600
#
#  conv2d_78 (Conv2D)          (None, 146, 146, 180)     324180
#
#  conv2d_79 (Conv2D)          (None, 144, 144, 180)     291780
#
#  conv2d_80 (Conv2D)          (None, 142, 142, 180)     291780
#
#  conv2d_81 (Conv2D)          (None, 140, 140, 180)     291780
#
#  max_pooling2d_20 (MaxPooli  (None, 28, 28, 180)       0
#  ng2D)
#
#  conv2d_82 (Conv2D)          (None, 26, 26, 180)       291780
#
#  conv2d_83 (Conv2D)          (None, 24, 24, 140)       226940
#
#  conv2d_84 (Conv2D)          (None, 22, 22, 100)       126100
#
#  conv2d_85 (Conv2D)          (None, 20, 20, 50)        45050
#
#  conv2d_86 (Conv2D)          (None, 18, 18, 50)        22550
#
#  max_pooling2d_21 (MaxPooli  (None, 3, 3, 50)          0
#  ng2D)
#
#  flatten_10 (Flatten)        (None, 450)               0
#
#  dense_36 (Dense)            (None, 180)               81180
#
#  dense_37 (Dense)            (None, 50)                9050
#
#  dropout_10 (Dropout)        (None, 50)                0
#
#  dense_38 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 2007821 (7.66 MB)
# Trainable params: 2007821 (7.66 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Now, lets train the model with validation split equal to 30% from training data. Validation split is used to determine that our model is not geting over-fitted.

# %%
import tensorflow as tf
# Include the epoch in the file name (uses `str.format`)
checkpoint_path = "./output/cp_NEW-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights every 1 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq=10)

# Save the weights using the `checkpoint_path` format
model.save_weights(checkpoint_path.format(epoch=0))

# Train the model with the new callback
trained = model.fit(Images,Labels,batch_size= 100, epochs=10,callbacks=[cp_callback],validation_split=0.20, verbose=1) #verbose meaning using or expressed in more words than are needed.
# Out:
# Epoch 1/10
#  9/14 [==================>...........] - ETA: 16s - loss: 1.1216 - accuracy: 0.4889
# Epoch 1: saving model to ./output/cp_NEW-0001.ckpt
# 14/14 [==============================] - 57s 4s/step - loss: 0.9792 - accuracy: 0.5063 - val_loss: 0.6795 - val_accuracy: 0.5816
# Epoch 2/10
#  5/14 [=========>....................] - ETA: 27s - loss: 0.7123 - accuracy: 0.4760
# Epoch 2: saving model to ./output/cp_NEW-0002.ckpt
# 14/14 [==============================] - 43s 3s/step - loss: 0.6996 - accuracy: 0.4981 - val_loss: 0.6810 - val_accuracy: 0.5816
# Epoch 3/10
#  1/14 [=>............................] - ETA: 39s - loss: 0.6831 - accuracy: 0.5700
# Epoch 3: saving model to ./output/cp_NEW-0003.ckpt
# 11/14 [======================>.......] - ETA: 9s - loss: 0.6945 - accuracy: 0.5345
# Epoch 3: saving model to ./output/cp_NEW-0003.ckpt
# 14/14 [==============================] - 43s 3s/step - loss: 0.6943 - accuracy: 0.5308 - val_loss: 0.6882 - val_accuracy: 0.5816
# Epoch 4/10
#  7/14 [==============>...............] - ETA: 21s - loss: 0.6930 - accuracy: 0.5129
# Epoch 4: saving model to ./output/cp_NEW-0004.ckpt
# 14/14 [==============================] - 43s 3s/step - loss: 0.6924 - accuracy: 0.5234 - val_loss: 0.6850 - val_accuracy: 0.5816
# Epoch 5/10
#  3/14 [=====>........................] - ETA: 33s - loss: 0.6948 - accuracy: 0.5100
# Epoch 5: saving model to ./output/cp_NEW-0005.ckpt
# 13/14 [==========================>...] - ETA: 3s - loss: 0.6932 - accuracy: 0.5154
# Epoch 5: saving model to ./output/cp_NEW-0005.ckpt
# 14/14 [==============================] - 43s 3s/step - loss: 0.6929 - accuracy: 0.5197 - val_loss: 0.6883 - val_accuracy: 0.5816
# Epoch 6/10
#  9/14 [==================>...........] - ETA: 15s - loss: 0.6915 - accuracy: 0.5344
# Epoch 6: saving model to ./output/cp_NEW-0006.ckpt
# 14/14 [==============================] - 43s 3s/step - loss: 0.6927 - accuracy: 0.5442 - val_loss: 0.6902 - val_accuracy: 0.5816
# Epoch 7/10
#  5/14 [=========>....................] - ETA: 27s - loss: 0.6925 - accuracy: 0.5420
# Epoch 7: saving model to ./output/cp_NEW-0007.ckpt
# 14/14 [==============================] - 43s 3s/step - loss: 0.6927 - accuracy: 0.5219 - val_loss: 0.6899 - val_accuracy: 0.5816
# Epoch 8/10
#  1/14 [=>............................] - ETA: 39s - loss: 0.6925 - accuracy: 0.4800
# Epoch 8: saving model to ./output/cp_NEW-0008.ckpt
# 11/14 [======================>.......] - ETA: 9s - loss: 0.6902 - accuracy: 0.5409
# Epoch 8: saving model to ./output/cp_NEW-0008.ckpt
# 14/14 [==============================] - 43s 3s/step - loss: 0.6916 - accuracy: 0.5345 - val_loss: 0.6882 - val_accuracy: 0.5816
# Epoch 9/10
#  7/14 [==============>...............] - ETA: 21s - loss: 0.6921 - accuracy: 0.5343
# Epoch 9: saving model to ./output/cp_NEW-0009.ckpt
# 14/14 [==============================] - 43s 3s/step - loss: 0.6924 - accuracy: 0.5278 - val_loss: 0.6901 - val_accuracy: 0.5816
# Epoch 10/10
#  3/14 [=====>........................] - ETA: 33s - loss: 0.6915 - accuracy: 0.5500
# Epoch 10: saving model to ./output/cp_NEW-0010.ckpt
# 13/14 [==========================>...] - ETA: 3s - loss: 0.6925 - accuracy: 0.5269
# Epoch 10: saving model to ./output/cp_NEW-0010.ckpt
# 14/14 [==============================] - 43s 3s/step - loss: 0.6922 - accuracy: 0.5293 - val_loss: 0.6856 - val_accuracy: 0.5816

# %%
# !ls {checkpoint_dir}
latest = tf.train.latest_checkpoint(checkpoint_dir)
latest
# Out:
# checkpoint			      cp_NEW-0005.ckpt.index
# cp_NEW-0000.ckpt.data-00000-of-00001  cp_NEW-0006.ckpt.data-00000-of-00001
# cp_NEW-0000.ckpt.index		      cp_NEW-0006.ckpt.index
# cp_NEW-0001.ckpt.data-00000-of-00001  cp_NEW-0007.ckpt.data-00000-of-00001
# cp_NEW-0001.ckpt.index		      cp_NEW-0007.ckpt.index
# cp_NEW-0002.ckpt.data-00000-of-00001  cp_NEW-0008.ckpt.data-00000-of-00001
# cp_NEW-0002.ckpt.index		      cp_NEW-0008.ckpt.index
# cp_NEW-0003.ckpt.data-00000-of-00001  cp_NEW-0009.ckpt.data-00000-of-00001
# cp_NEW-0003.ckpt.index		      cp_NEW-0009.ckpt.index
# cp_NEW-0004.ckpt.data-00000-of-00001  cp_NEW-0010.ckpt.data-00000-of-00001
# cp_NEW-0004.ckpt.index		      cp_NEW-0010.ckpt.index
# cp_NEW-0005.ckpt.data-00000-of-00001
# './output/cp_NEW-0010.ckpt'

# %% [markdown]
# **Load a Trained Model**

# %%
chk_path= './output/cp_NEW-0010.ckpt'
# Load the previously saved weights
model.load_weights(chk_path)

# %% [markdown]
# **Plot Training and Testing Graphs**

# %%
plot.plot(trained.history['accuracy'])
plot.plot(trained.history['val_accuracy'])
plot.title('Model accuracy')
plot.ylabel('Accuracy')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

plot.plot(trained.history['loss'])
plot.plot(trained.history['val_loss'])
plot.title('Model loss')
plot.ylabel('Loss')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

# %% [markdown]
# To evaluate a model, there are many methods are proposed to evaluate the model. I use Accuracy to evaluate the performance of my model.

# %%
test_images,test_labels = get_images('/content/drive/MyDrive/Radiology_workshop_monjoy/classification_raw_data/test_data/')
test_images = np.array(test_images)
test_labels = np.array(test_labels)
model.evaluate(test_images,test_labels, verbose=1)
# Out:
# 1/1 [==============================] - 5s 5s/step - loss: 0.6963 - accuracy: 0.4286
# [0.6963034868240356, 0.4285714328289032]

# %% [markdown]
# Lets predict the images from the "pred" folder.

# %%
y_pred = model.predict(test_images)
y_pred= y_pred.round()
#y_pred
# Out:
# 1/1 [==============================] - 0s 142ms/step

# %%
len(test_labels)
# Out:
# 21

# %% [markdown]
# **Generate a classification report**

# %%
from sklearn.metrics import classification_report
report = classification_report(test_labels, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      1.00      0.60         9
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.43        21
#    macro avg       0.21      0.50      0.30        21
# weighted avg       0.18      0.43      0.26        21
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Plot Prediction Results**

# %%
fig = plot.figure(figsize=(30, 30))
outer = gridspec.GridSpec(5, 5, wspace=0.2, hspace=0.2)

for i in range(21):
    inner = gridspec.GridSpecFromSubplotSpec(2, 1,subplot_spec=outer[i], wspace=0.1, hspace=0.1)
    rnd_number = randint(0,len(test_images))
    pred_image = np.array([test_images[i]])
    pred_prob = model.predict(pred_image)[0]
    #print(pred_prob)
    for j in range(2):
        if (j%2) == 0:
            ax = plot.Subplot(fig, inner[j])
            ax.imshow(pred_image[0])
            if pred_prob <0.5:
               ax.set_title('Normal')
            else:
               ax.set_title('COVID-19')
            ax.set_xticks([])
            ax.set_yticks([])
            fig.add_subplot(ax)
fig.show()
# Out:
# 1/1 [==============================] - 1s 814ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
