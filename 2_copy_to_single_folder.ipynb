# %% [markdown]
# **Mounting Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **Load packages**

# %%
import os
from os.path import join, isfile
import shutil
import time

# %% [markdown]
# **Data Source and Destination paths**

# %%
root_dir = '/content/drive/MyDrive/Radiology_workshop_monjoy/save_pngs_path/COVID-19'
dest_dir = '/content/drive/MyDrive/Radiology_workshop_monjoy/single_data_folder/COVID-19/'
os.listdir(root_dir)
# Out:
# ['study_1097',
#  'study_1094',
#  'study_1101',
#  'study_1096',
#  'study_1100',
#  'study_1109',
#  'study_1095',
#  'study_1093',
#  'study_1099',
#  'study_1103',
#  'study_1108',
#  'study_1104',
#  'study_1098',
#  'study_1107',
#  'study_1110',
#  'study_1102',
#  'study_1105',
#  'study_1106']

# %%
if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)
        print("Created ouput directory: " + dest_dir)
for folder in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder)
    if os.path.isdir(folder_path): 
       subfolder_path = os.path.join(root_dir, folder)
       #print(subfolder_path)
       for filename in os.listdir(subfolder_path):
           file_path = os.path.join(root_dir, folder, filename)
           #dest_path = os.path.join(dest_dir, filename)
           fname, ext = os.path.splitext(filename)
           timestr = time.strftime("%Y%m%d-%H%M%S")
           #print(fname+timestr)
           dest_path = os.path.join(dest_dir, fname+timestr+'.png')
           #print(dest_path)
           shutil.copy(file_path, dest_path)
           print("Copied ", file_path, "to", dest_path)
# Out:
# Created ouput directory: /content/drive/MyDrive/Radiology_workshop_monjoy/single_data_folder/COVID-19/
# Copied  /content/drive/MyDrive/Radiology_workshop_monjoy/save_pngs_path/COVID-19/study_1097/study__z003.png to /content/drive/MyDrive/Radiology_workshop_monjoy/single_data_folder/COVID-19/study__z00320210606-144256.png
# Copied  /content/drive/MyDrive/Radiology_workshop_monjoy/save_pngs_path/COVID-19/study_1097/study__z004.png to /content/drive/MyDrive/Radiology_workshop_monjoy/single_data_folder/COVID-19/study__z00420210606-144256.png
# Copied  /content/drive/MyDrive/Radiology_workshop_monjoy/save_pngs_path/COVID-19/study_1097/study__z001.png to /content/drive/MyDrive/Radiology_workshop_monjoy/single_data_folder/COVID-19/study__z00120210606-144256.png
# Copied  /content/drive/MyDrive/Radiology_workshop_monjoy/save_pngs_path/COVID-19/study_1097/study__z002.png to /content/drive/MyDrive/Radiology_workshop_monjoy/single_data_folder/COVID-19/study__z00220210606-144256.png
# ...
